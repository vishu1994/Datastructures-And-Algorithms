# %%
class Stack:
    
    def __init__(self,maxsize):
        self.maxsize=maxsize
        self.array=[None]*maxsize
        self.top=-1
        print(self.array)
        
    
    
    def push(self,data):
        
        if self.top is self.maxsize-1:
            print("stack overflow")
            return
        
        self.top=self.top+1
        #print(self.top)
        self.array[self.top]=data

    
    def pop(self):
        
        if(self.top==-1):
            print("stack underflow")
            return
        
        popped=self.array[self.top]
        self.top=self.top-1
        
    
    
    def isEmpty(self):
        
        if self.top is -1:
            return True
        
        else:
            return False
        
    
    
    def peek(self):
        return self.array[top]
    
    
    def printstack(self):
        
        for i in range(self.top+1):
            print(self.array[i],end=" ")
    
    
    
    
stack=Stack(5)
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)

stack.push(5)

stack.printstack()

stack.pop()
stack.pop()
print()

stack.printstack()

stack.pop()
stack.pop()

print()

stack.printstack()

stack.pop()
stack.pop()
# Out:
# [None, None, None, None, None]
# 1 2 3 4 5
# 1 2 3
# 1 stack underflow
